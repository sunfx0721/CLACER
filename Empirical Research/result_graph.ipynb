# %% [markdown]
# # 导入依赖

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rcParams

import numpy as np
import pandas as pd

# %%
# 字体设置
plt.rc('font',family='Times New Roman')
# config = {
#     "font.family":'serif',
#     "font.size": 14,
#     "mathtext.fontset":'stix',
#     "font.serif": ['SimSun'],
# }
# rcParams.update(config)
# 预定义颜色 RGB
color_2 = '#F77770'
color_1 = '#18B947'
color_3 = '#629CFA'

# %% [markdown]
# ## 获取类别标签

# %%
class_label = pd.read_excel("result_for_graph/class_label.xlsx",sheet_name="ClassLabel")

# %% [markdown]
# # 绘制分组柱形图
# # RQ2

# %% [markdown]
# ## 1 distribution of error category

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="RealDataset")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "deepfixS"
colName_2 = "tegcer"

# %%
x = np.arange(data.shape[0])  # the label locations
y = np.arange(0.0, 0.55, 0.1)  # the label locations

# x_labels = ['$\mathrm{' + x_i[1:-1] + '}$' for x_i in data[colLabel]]
x_labels = data[colLabel]
y_labels = [str(int(y_i*100))+'%' for y_i in y]
width = 0.35  # the width of the bars

fig, ax = plt.subplots()

# rects1 = ax.bar(x - width/2, data[colName_1], width, color='lightsteelblue',edgecolor='royalblue', label='deepfixS')
# rects2 = ax.bar(x + width/2, data[colName_2], width, color='black', label='tegcer')
rects1 = ax.bar(x - width/2, data[colName_1], width, color=color_1, label='deepfixS')
rects2 = ax.bar(x + width/2, data[colName_2], width, color=color_2, label='tegcer')

# ax.plot(x - width/2, data[colName_1], color='#7b8dbf', marker='*')

ax.set_xlabel('ClassID')
ax.set_ylabel('Percentage')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(x_labels)

ax.set_yticks(y)
ax.set_yticklabels(y_labels)

ax.legend()

plt.grid(b=True, axis='y')
# plt.tight_layout()
# plt.savefig('result_for_graph/graph/test.pdf', bbox_inches='tight')
plt.savefig('result_for_graph/graph/RQ2/distribution of error category.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 2 DeepFix_mutate_traindata

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="Mutate")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "deepfixS"
colName_2 = "mutate"

# %%
x = np.arange(data.shape[0])  # the label locations
y = np.arange(0.0, 0.55, 0.1)  # the label locations

# x_labels = ['$\mathrm{' + x_i[1:-1] + '}$' for x_i in data[colLabel]]
x_labels = data[colLabel]
y_labels = [str(int(y_i*100))+'%' for y_i in y]
width = 0.35  # the width of the bars

fig, ax = plt.subplots()

# rects1 = ax.bar(x - width/2, data[colName_1], width, color='lightsteelblue',edgecolor='royalblue', label='deepfixS')
# rects2 = ax.bar(x + width/2, data[colName_2], width, color='black', label='tegcer')
rects1 = ax.bar(x - width/2, data[colName_1], width, color=color_1, label='deepfixS')
rects2 = ax.bar(x + width/2, data[colName_2], width, color=color_2, label='mutate')

# ax.plot(x - width/2, data[colName_1], color='#7b8dbf', marker='*')

ax.set_xlabel('ClassID')
ax.set_ylabel('Percentage')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(x_labels)

ax.set_yticks(y)
ax.set_yticklabels(y_labels)

ax.legend()

plt.grid(b=True, axis='y')
plt.savefig('result_for_graph/graph/RQ2/DeepFix_mutate_traindata.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3 DeepFix_muate_with_ids_traindata

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="Mutate_ids")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "deepfixS"
colName_2 = "mutate_ids"

# %%
x = np.arange(data.shape[0])  # the label locations
y = np.arange(0.0, 0.55, 0.1)  # the label locations

# x_labels = ['$\mathrm{' + x_i[1:-1] + '}$' for x_i in data[colLabel]]
x_labels = data[colLabel]
y_labels = [str(int(y_i*100))+'%' for y_i in y]
width = 0.35  # the width of the bars

fig, ax = plt.subplots()

# rects1 = ax.bar(x - width/2, data[colName_1], width, color='lightsteelblue',edgecolor='royalblue', label='deepfixS')
# rects2 = ax.bar(x + width/2, data[colName_2], width, color='black', label='tegcer')
rects1 = ax.bar(x - width/2, data[colName_1], width, color=color_1, label='deepfixS')
rects2 = ax.bar(x + width/2, data[colName_2], width, color=color_2, label='mutate')

# ax.plot(x - width/2, data[colName_1], color='#7b8dbf', marker='*')

ax.set_xlabel('ClassID')
ax.set_ylabel('Percentage')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(x_labels)

ax.set_yticks(y)
ax.set_yticklabels(y_labels)

ax.legend()

plt.grid(b=True, axis='y')
plt.savefig('result_for_graph/graph/RQ2/DeepFix_muate_with_ids_traindata.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # RQ3

# %% [markdown]
# ## 4 DeepFix_distribution

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="DeepFix_distribution")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "deepfixS"
colName_2 = "tegcer"

# %%
x = np.arange(data.shape[0])  # the label locations
y = np.arange(0.0, 1.05, 0.1)  # the label locations

# x_labels = ['$\mathrm{' + x_i[1:-1] + '}$' for x_i in data[colLabel]]
x_labels = data[colLabel]
y_labels = [str(int(y_i*100))+'%' for y_i in y]
width = 0.35  # the width of the bars

fig, ax = plt.subplots()

# rects1 = ax.bar(x - width/2, data[colName_1], width, color='lightsteelblue',edgecolor='royalblue', label='deepfixS')
# rects2 = ax.bar(x + width/2, data[colName_2], width, color='black', label='tegcer')
rects1 = ax.bar(x - width/2, data[colName_1], width, color=color_1, label='deepfixS')
rects2 = ax.bar(x + width/2, data[colName_2], width, color=color_2, label='tegcer')

# ax.plot(x - width/2, data[colName_1], color='#7b8dbf', marker='*')

ax.set_xlabel('ClassID')
ax.set_ylabel('Percentage')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(x_labels)

ax.set_yticks(y)
ax.set_yticklabels(y_labels)

ax.legend()

plt.grid(b=True, axis='y')
plt.savefig('result_for_graph/graph/RQ3/DeepFix_distribution.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 5 RLAssist_distribution

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="RLAssist_distribution")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "deepfixS"
colName_2 = "tegcer"

# %%
x = np.arange(data.shape[0])  # the label locations
y = np.arange(0.0, 1.05, 0.1)  # the label locations

# x_labels = ['$\mathrm{' + x_i[1:-1] + '}$' for x_i in data[colLabel]]
x_labels = data[colLabel]
y_labels = [str(int(y_i*100))+'%' for y_i in y]
width = 0.35  # the width of the bars

fig, ax = plt.subplots()

# rects1 = ax.bar(x - width/2, data[colName_1], width, color='lightsteelblue',edgecolor='royalblue', label='deepfixS')
# rects2 = ax.bar(x + width/2, data[colName_2], width, color='black', label='tegcer')
rects1 = ax.bar(x - width/2, data[colName_1], width, color=color_1, label='deepfixS')
rects2 = ax.bar(x + width/2, data[colName_2], width, color=color_2, label='tegcer')

# ax.plot(x - width/2, data[colName_1], color='#7b8dbf', marker='*')

ax.set_xlabel('ClassID')
ax.set_ylabel('Percentage')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(x_labels)

ax.set_yticks(y)
ax.set_yticklabels(y_labels)

ax.legend()

plt.grid(b=True, axis='y')
plt.savefig('result_for_graph/graph/RQ3/RLAssist_distribution.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6 MACER_distribution

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="MACER_distribution")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "deepfixS"
colName_2 = "tegcer"

# %%
x = np.arange(data.shape[0])  # the label locations
y = np.arange(0.0, 1.05, 0.1)  # the label locations

# x_labels = ['$\mathrm{' + x_i[1:-1] + '}$' for x_i in data[colLabel]]
x_labels = data[colLabel]
y_labels = [str(int(y_i*100))+'%' for y_i in y]
width = 0.35  # the width of the bars

fig, ax = plt.subplots()

# rects1 = ax.bar(x - width/2, data[colName_1], width, color='lightsteelblue',edgecolor='royalblue', label='deepfixS')
# rects2 = ax.bar(x + width/2, data[colName_2], width, color='black', label='tegcer')
rects1 = ax.bar(x - width/2, data[colName_1], width, color=color_1, label='deepfixS')
rects2 = ax.bar(x + width/2, data[colName_2], width, color=color_2, label='tegcer')

# ax.plot(x - width/2, data[colName_1], color='#7b8dbf', marker='*')

ax.set_xlabel('ClassID')
ax.set_ylabel('Percentage')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(x_labels)

ax.set_yticks(y)
ax.set_yticklabels(y_labels)

ax.legend()

plt.grid(b=True, axis='y')
plt.savefig('result_for_graph/graph/RQ3/MACER_distribution.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 7 deepfixS_compare_bar

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="deepfixS_repair_result")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "DeepFix"
colName_2 = "RLAssist"
colName_3 = "MACER"

# %%
x = np.arange(0, data.shape[0]*2, 2)  # the label locations
y = np.arange(0.0, 1.05, 0.1)  # the label locations

# x_labels = ['$\mathrm{' + x_i[1:-1] + '}$' for x_i in data[colLabel]]
x_labels = data[colLabel]
y_labels = [str(int(y_i*100))+'%' for y_i in y]
width = 0.52  # the width of the bars

fig, ax = plt.subplots()

# rects1 = ax.bar(x - width/2, data[colName_1], width, color='lightsteelblue',edgecolor='royalblue', label='deepfixS')
# rects2 = ax.bar(x + width/2, data[colName_2], width, color='black', label='tegcer')
rects1 = ax.bar(x + -1 * width, data[colName_1], width, color=color_1, label='DeepFix')
rects2 = ax.bar(x +  0 * width, data[colName_2], width, color=color_2, label='RLAssist')
rects3 = ax.bar(x +  1 * width, data[colName_3], width, color=color_3, label='MACER')

# ax.plot(x - width/2, data[colName_1], color='#7b8dbf', marker='*')

ax.set_xlabel('ClassID')
ax.set_ylabel('Percentage')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(x_labels)

ax.set_yticks(y)
ax.set_yticklabels(y_labels)

ax.legend()

plt.grid(b=True, axis='y')
plt.savefig('result_for_graph/graph/RQ3/deepfixS_compare_bar.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 8 tegcer_compare_bar

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="tegcer_repair_result")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "DeepFix"
colName_2 = "RLAssist"
colName_3 = "MACER"

# %%
x = np.arange(0, data.shape[0]*2, 2)  # the label locations
y = np.arange(0.0, 1.05, 0.1)  # the label locations

# x_labels = ['$\mathrm{' + x_i[1:-1] + '}$' for x_i in data[colLabel]]
x_labels = data[colLabel]
y_labels = [str(int(y_i*100))+'%' for y_i in y]
width = 0.52  # the width of the bars

fig, ax = plt.subplots()

# rects1 = ax.bar(x - width/2, data[colName_1], width, color='lightsteelblue',edgecolor='royalblue', label='deepfixS')
# rects2 = ax.bar(x + width/2, data[colName_2], width, color='black', label='tegcer')
rects1 = ax.bar(x + -1 * width, data[colName_1], width, color=color_1, label='DeepFix')
rects2 = ax.bar(x +  0 * width, data[colName_2], width, color=color_2, label='RLAssist')
rects3 = ax.bar(x +  1 * width, data[colName_3], width, color=color_3, label='MACER')

# ax.plot(x - width/2, data[colName_1], color='#7b8dbf', marker='*')

ax.set_xlabel('ClassID')
ax.set_ylabel('Percentage')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(x_labels)

ax.set_yticks(y)
ax.set_yticklabels(y_labels)

ax.legend()

plt.grid(b=True, axis='y')
plt.savefig('result_for_graph/graph/RQ3/tegcer_compare_bar.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 9 r_vs_d

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="r_vs_d")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "DmR"
colName_2 = "RmD"

# %%
x = np.arange(data.shape[0])  # the label locations

# x_labels = ['$\mathrm{' + x_i[1:-1] + '}$' for x_i in data[colLabel]]
x_labels = data[colLabel]
width = 0.35  # the width of the bars

fig, ax = plt.subplots()

rects1 = ax.bar(x - width/2, data[colName_1], width, color=color_1, label=colName_1)
rects2 = ax.bar(x + width/2, data[colName_2], width, color=color_2, label=colName_2)

# ax.plot(x - width/2, data[colName_1], color='#7b8dbf', marker='*')

ax.set_xlabel('ClassID')
ax.set_ylabel('Count')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(x_labels)

ax.legend()

plt.grid(b=True, axis='y')
plt.savefig('result_for_graph/graph/RQ3/r_vs_d.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 10 m_vs_rad

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="m_vs_rad")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "RaD_mM"
colName_2 = "Mm_RaD"

# %%
step = 1
x = np.arange(0, data.shape[0]*step, step)  # the label locations
y = np.arange(0, 5, 1)

x_labels = data[colLabel]
y_labels = [10**i for i in y]
width = 0.35  # the width of the bars

fig, ax = plt.subplots()

rects1 = ax.bar(x - width/2, np.log10(data[colName_1]), width, color=color_1, label=colName_1)
rects2 = ax.bar(x + width/2, np.log10(data[colName_2]), width, color=color_2, label=colName_2)

# ax.plot(x - width/2, data[colName_1], color='#7b8dbf', marker='*')

ax.set_xlabel('ClassID')
ax.set_ylabel('lg(Count)')
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xticks(x)
ax.set_xticklabels(x_labels)

ax.set_yticks(y)
ax.set_yticklabels(y_labels)

for x_i, y_i, value_i in zip(x - width/2, np.log10(data[colName_1]).tolist(), data[colName_1].tolist()): plt.text(x_i,y_i+0.05,'%s' %value_i,ha='center') # show the values
for x_i, y_i, value_i in zip(x + width/2, np.log10(data[colName_2]).tolist(), data[colName_2].tolist()): plt.text(x_i,y_i+0.05,'%s' %value_i,ha='center') # show the values

ax.legend()

plt.grid(b=True, axis='y')
plt.savefig('result_for_graph/graph/RQ3/m_vs_rad.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # 绘制雷达图

# %% [markdown]
# ## 11 deepfixS_compare_radar

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="deepfixS_repair_result")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "DeepFix"
colName_2 = "RLAssist"
colName_3 = "MACER"

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.patches import Circle, RegularPolygon
from matplotlib.path import Path
from matplotlib.projections.polar import PolarAxes
from matplotlib.projections import register_projection
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D


def radar_factory(num_vars, frame='circle'):
    """
    Create a radar chart with `num_vars` axes.

    This function creates a RadarAxes projection and registers it.

    Parameters
    ----------
    num_vars : int
        Number of variables for radar chart.
    frame : {'circle', 'polygon'}
        Shape of frame surrounding axes.

    """
    # calculate evenly-spaced axis angles
    theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

    class RadarAxes(PolarAxes):

        name = 'radar'
        # use 1 line segment to connect specified points
        RESOLUTION = 1

        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
            # rotate plot such that the first axis is at the top
            self.set_theta_zero_location('N')

        def fill(self, *args, closed=True, **kwargs):
            """Override fill so that line is closed by default"""
            return super().fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            """Override plot so that line is closed by default"""
            lines = super().plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            # FIXME: markers at x[0], y[0] get doubled-up
            if x[0] != x[-1]:
                x = np.append(x, x[0])
                y = np.append(y, y[0])
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels)

        def _gen_axes_patch(self):
            # The Axes patch must be centered at (0.5, 0.5) and of radius 0.5
            # in axes coordinates.
            if frame == 'circle':
                return Circle((0.5, 0.5), 0.5)
            elif frame == 'polygon':
                return RegularPolygon((0.5, 0.5), num_vars,
                                      radius=.5, edgecolor="k")
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

        def _gen_axes_spines(self):
            if frame == 'circle':
                return super()._gen_axes_spines()
            elif frame == 'polygon':
                # spine_type must be 'left'/'right'/'top'/'bottom'/'circle'.
                spine = Spine(axes=self,
                              spine_type='circle',
                              path=Path.unit_regular_polygon(num_vars))
                # unit_regular_polygon gives a polygon of radius 1 centered at
                # (0, 0) but we want a polygon of radius 0.5 centered at (0.5,
                # 0.5) in axes coordinates.
                spine.set_transform(Affine2D().scale(.5).translate(.5, .5)
                                    + self.transAxes)
                return {'polar': spine}
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

    register_projection(RadarAxes)
    return theta

def get_data(data):
    """
    获取雷达图数据
    :param data:Dataframe
    :return: data
    """
    data_for_radar = [
        data[colLabel].tolist(),
        [
            data[colName_1].tolist(),
            data[colName_2].tolist(),
            data[colName_3].tolist(),
        ]
    ]
    return data_for_radar

# %%
N = 13
theta = radar_factory(N, frame='polygon')
# theta = radar_factory(N, frame='circle')

data = get_data(data)

# %%
spoke_labels = data[0]
fig, ax = plt.subplots(figsize=(5, 5), nrows=1, ncols=1,
                        subplot_kw=dict(projection='radar'))
fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

colors = [color_1, color_2, color_3]
# Plot the four cases from the example data on separate axes
ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
for d, color in zip(data[1], colors):
    ax.plot(theta, d, color=color)
    ax.fill(theta, d, facecolor=color, alpha=0.25)
ax.set_varlabels(spoke_labels)

# add legend relative to top-left plot
labels = ('DeepFix', 'RLAssist', 'MACER')
legend = ax.legend(labels, loc=(0.9, .95),
                          labelspacing=0.1,)  # fontsize='small')
plt.savefig('result_for_graph/graph/RQ3/deepfixS_compare_radar.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 12 tegcer_compare_radar

# %%
data = pd.read_excel("result_for_graph/result_for_bar.xlsx",sheet_name="tegcer_repair_result")
data = data.merge(class_label, how='inner', on='错误类别')
data = data.sort_values(by='ClassID')
colLabel = "ClassID_tex"
colName_1 = "DeepFix"
colName_2 = "RLAssist"
colName_3 = "MACER"

# %%
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.patches import Circle, RegularPolygon
from matplotlib.path import Path
from matplotlib.projections.polar import PolarAxes
from matplotlib.projections import register_projection
from matplotlib.spines import Spine
from matplotlib.transforms import Affine2D


def radar_factory(num_vars, frame='circle'):
    """
    Create a radar chart with `num_vars` axes.

    This function creates a RadarAxes projection and registers it.

    Parameters
    ----------
    num_vars : int
        Number of variables for radar chart.
    frame : {'circle', 'polygon'}
        Shape of frame surrounding axes.

    """
    # calculate evenly-spaced axis angles
    theta = np.linspace(0, 2*np.pi, num_vars, endpoint=False)

    class RadarAxes(PolarAxes):

        name = 'radar'
        # use 1 line segment to connect specified points
        RESOLUTION = 1

        def __init__(self, *args, **kwargs):
            super().__init__(*args, **kwargs)
            # rotate plot such that the first axis is at the top
            self.set_theta_zero_location('N')

        def fill(self, *args, closed=True, **kwargs):
            """Override fill so that line is closed by default"""
            return super().fill(closed=closed, *args, **kwargs)

        def plot(self, *args, **kwargs):
            """Override plot so that line is closed by default"""
            lines = super().plot(*args, **kwargs)
            for line in lines:
                self._close_line(line)

        def _close_line(self, line):
            x, y = line.get_data()
            # FIXME: markers at x[0], y[0] get doubled-up
            if x[0] != x[-1]:
                x = np.append(x, x[0])
                y = np.append(y, y[0])
                line.set_data(x, y)

        def set_varlabels(self, labels):
            self.set_thetagrids(np.degrees(theta), labels)

        def _gen_axes_patch(self):
            # The Axes patch must be centered at (0.5, 0.5) and of radius 0.5
            # in axes coordinates.
            if frame == 'circle':
                return Circle((0.5, 0.5), 0.5)
            elif frame == 'polygon':
                return RegularPolygon((0.5, 0.5), num_vars,
                                      radius=.5, edgecolor="k")
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

        def _gen_axes_spines(self):
            if frame == 'circle':
                return super()._gen_axes_spines()
            elif frame == 'polygon':
                # spine_type must be 'left'/'right'/'top'/'bottom'/'circle'.
                spine = Spine(axes=self,
                              spine_type='circle',
                              path=Path.unit_regular_polygon(num_vars))
                # unit_regular_polygon gives a polygon of radius 1 centered at
                # (0, 0) but we want a polygon of radius 0.5 centered at (0.5,
                # 0.5) in axes coordinates.
                spine.set_transform(Affine2D().scale(.5).translate(.5, .5)
                                    + self.transAxes)
                return {'polar': spine}
            else:
                raise ValueError("Unknown value for 'frame': %s" % frame)

    register_projection(RadarAxes)
    return theta

def get_data(data):
    """
    获取雷达图数据
    :param data:Dataframe
    :return: data
    """
    data_for_radar = [
        data[colLabel].tolist(),
        [
            data[colName_1].tolist(),
            data[colName_2].tolist(),
            data[colName_3].tolist(),
        ]
    ]
    return data_for_radar

# %%
N = 13
theta = radar_factory(N, frame='polygon')
# theta = radar_factory(N, frame='circle')

data = get_data(data)

# %%
spoke_labels = data[0]
fig, ax = plt.subplots(figsize=(5, 5), nrows=1, ncols=1,
                        subplot_kw=dict(projection='radar'))
fig.subplots_adjust(wspace=0.25, hspace=0.20, top=0.85, bottom=0.05)

colors = [color_1, color_2, color_3]
# Plot the four cases from the example data on separate axes
ax.set_rgrids([0.2, 0.4, 0.6, 0.8])
for d, color in zip(data[1], colors):
    ax.plot(theta, d, color=color)
    ax.fill(theta, d, facecolor=color, alpha=0.25)
ax.set_varlabels(spoke_labels)

# add legend relative to top-left plot
labels = ('DeepFix', 'RLAssist', 'MACER')
legend = ax.legend(labels, loc=(0.9, .95),
                          labelspacing=0.1,)  # fontsize='small')
plt.savefig('result_for_graph/graph/RQ3/tegcer_compare_radar.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Venn图

# %% [markdown]
# ## 13 repair_venn

# %%
def draw_venn3(subsets):
    import matplotlib.pyplot as plt
    from matplotlib_venn import venn3, venn3_circles

    my_dpi = 200
    plt.figure(figsize=(1200/my_dpi, 1200/my_dpi), dpi=my_dpi)  # 控制图尺寸的同时，使图高分辨率（高清）显示
    g = venn3(subsets=subsets,  # 传入三组数据
              set_labels=("DeepFix", "RLAssist", "MACER"),  # 设置组名
              set_colors=(color_1, color_2, color_3),  # 设置圈的颜色，中间颜色不能修改
              alpha=0.5,  # 透明度
              normalize_to=1.0,  # venn图占据figure的比例，1.0为占满
              )
    g = venn3_circles(subsets=subsets,
                      linestyle='--', linewidth=0.8, color="black"  # 外框线型、线宽、颜色
                      )
    plt.savefig('result_for_graph/graph/RQ3/repair_venn.pdf', bbox_inches='tight')
    plt.show()

result_all = pd.read_excel(r"data/ALL_fix_state.xlsx", sheet_name="ALL_fix_state")

# %%
deepfix_set = set(result_all.groupby("deepfix").get_group("CompletelyFixed")["program_id"])
rlassist_set = set(result_all.groupby("rlassist").get_group("CompletelyFixed")["program_id"])
macer_set = set(result_all.groupby("macer").get_group("CompletelyFixed")["program_id"])

draw_venn3([deepfix_set, rlassist_set, macer_set])
